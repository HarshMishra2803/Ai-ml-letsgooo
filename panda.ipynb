# %%
import pandas as pd
import numpy as np

# %%
info = {
    "Name" : ["Harsh","Rahul","Shreya"],
    "CGPA" : ["9.5","8.3","8.8"]
}
df = pd.DataFrame(info)

# %%
print(df)
# Out:
#      Name CGPA
# 0   Harsh  9.5
# 1   Rahul  8.3
# 2  Shreya  8.8

# %%
df
# Out:
#      Name CGPA
# 0   Harsh  9.5
# 1   Rahul  8.3
# 2  Shreya  8.8

# %%
#series 1 dimensional labeled array
s= pd.Series([1,2,3,4,5])
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
print(type(s))
print(s[0])
# Out:
# <class 'pandas.Series'>
# 1

# %%
print(s[3])
# Out:
# 4

# %%
s = pd.Series(["23","21","25","31"],index =["Adam","eva","finch","sachin"])
print(s)
s
# Out:
# Adam      23
# eva       21
# finch     25
# sachin    31
# dtype: str
# Adam      23
# eva       21
# finch     25
# sachin    31
# dtype: str

# %%
print(s["Adam"])
print(s["sachin"])
# Out:
# 23
# 31

# %%
print(s.index)
# Out:
# Index(['Adam', 'eva', 'finch', 'sachin'], dtype='str')

# %%
# property
# homogenous,vectorized operation
#handle missing value with Nan
#mutable value , immutable size

# %%
 # data Frames  - 2D labelled Array

# %%
info = {
    "Name" : ["Adam" , "eve"],
    "Age":[21,24],
    "CGPA":[9.8,9.4],


}

# %%
df = pd.DataFrame(info)
print(df,type(df))
# Out:
#    Name  Age  CGPA
# 0  Adam   21   9.8
# 1   eve   24   9.4 <class 'pandas.DataFrame'>

# %%
df
# Out:
#    Name  Age  CGPA
# 0  Adam   21   9.8
# 1   eve   24   9.4

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
print(df.columns)
# Out:
# Index(['Name', 'Age', 'CGPA'], dtype='str')

# %%
df = pd.DataFrame([["Harsh",21],["Virat",33],["Rohit",36]],columns=["Name","Age"])

# %%
print(df)
# Out:
#     Name  Age
# 0  Harsh   21
# 1  Virat   33
# 2  Rohit   36

# %%
np_arr=np.array([[1,2,3],[4,5,6]])
df = pd.DataFrame(np_arr,columns  = ["A","B","C"])

# %%
print(df)
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %%
# csv file 
df = pd.read_csv("employee_data.csv")
print(df,type(df))
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000 <class 'pandas.DataFrame'>

# %%
df
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000

# %%
df
# json data
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000

# %%
#df = pd.read_json("employee_data.json")
#print(df,type(df))

# %%
# data frame methods

df = pd.read_csv("employee_data.csv")
print(df,type(df))
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000 <class 'pandas.DataFrame'>

# %%
df
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000

# %%
# Methods 
print( df.head()) # it  gives initial five rows of a table
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000

# %%
df.head()
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000

# %%
df.tail()
# Out:
#    ID    Name  Age Department  Salary
# 5   6   Frank   29    Finance   50000
# 6   7   Grace   41         HR   82000
# 7   8  Hannah   26  Marketing   47000
# 8   9     Ian   35         IT   75000
# 9  10   Julia   30    Finance   60000

# %%
df.tail(2)
# Out:
#    ID   Name  Age Department  Salary
# 8   9    Ian   35         IT   75000
# 9  10  Julia   30    Finance   60000

# %%
df.sample()
# Out:
#    ID   Name  Age Department  Salary
# 0   1  Alice   25         HR   55000

# %%
df.sample()
# Out:
#    ID   Name  Age Department  Salary
# 6   7  Grace   41         HR   82000

# %%
df.sample(5)
# Out:
#    ID   Name  Age Department  Salary
# 0   1  Alice   25         HR   55000
# 8   9    Ian   35         IT   75000
# 1   2    Bob   32         IT   72000
# 3   4  David   45  Marketing   91000
# 9  10  Julia   30    Finance   60000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          10 non-null     int64
#  1   Name        10 non-null     str
#  2   Age         10 non-null     int64
#  3   Department  10 non-null     str
#  4   Salary      10 non-null     int64
# dtypes: int64(3), str(2)
# memory usage: 532.0 bytes

# %%
df.shape
# Out:
# (10, 5)

# %%
df.describe()
# Out:
#              ID        Age        Salary
# count  10.00000  10.000000     10.000000
# mean    5.50000  32.900000  64500.000000
# std     3.02765   6.674162  15182.226451
# min     1.00000  25.000000  47000.000000
# 25%     3.25000  28.250000  51250.000000
# 50%     5.50000  31.000000  62500.000000
# 75%     7.75000  37.250000  74250.000000
# max    10.00000  45.000000  91000.000000

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Department', 'Salary'], dtype='str')

# %%
df.nunique()
# Out:
# ID            10
# Name          10
# Age           10
# Department     4
# Salary        10
# dtype: int64
