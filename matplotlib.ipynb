# %%
# matplotlib - library for data  visualization

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [5,6,7,8,9]

plt.plot(x,y)
plt.show()

# %%
# Real data

# Oscar Winner Movies
oscar_movies = [
    "The Dark Knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Argo"
]

years = [2008, 2009, 2010, 2011, 2012]

oscar_revenue = [1005, 170, 427, 133, 232]  # in $M

# %%
# plot data now 
plt.plot(years,oscar_revenue)
plt.title("Oscar Movie Revenue In Each Year")
plt.xlabel("Years")
plt.ylabel("Revenue (in $M)")
plt.show()

# %%
# Non-Oscar Winner Movies
non_oscar_movies = [
    "Slumdog Millionaire",
    "Avatar",
    "Inception",
    "Hugo",
    "Lincoln"
]
non_oscar_revenue = [378, 2788, 829, 185, 275]  # in $M

# %%
plt.plot(years,oscar_revenue,"o--r",label = "Oscar Movies")
plt.plot(years,non_oscar_revenue , label = "Non Oscar Movies")


plt.title("Oscar movie Vs Non Oscar Movie Revenue")
plt.xlabel("Years")
plt.ylabel("Revenue (in $M)")

plt.legend()
# plt.legend(loc = "upper left")

# plt.style.available

# plt.style.use("dark_background")
# plt.style.use("ggplot")
# plt.grid()
# plt.style.use("xkcd")

# %%
plt.bar(years,oscar_revenue)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(years,oscar_revenue)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.scatter(years,oscar_revenue)

# %%
plt.pie(oscar_revenue)
# Out:
# ([<matplotlib.patches.Wedge at 0x11cec9590>,
#   <matplotlib.patches.Wedge at 0x11cec9810>,
#   <matplotlib.patches.Wedge at 0x11cec9a90>,
#   <matplotlib.patches.Wedge at 0x11cec9d10>,
#   <matplotlib.patches.Wedge at 0x11cec9f90>],
#  [Text(-0.037765209213943836, 1.0993515311186988, ''),
#   Text(-1.0369593566863287, -0.36703581920662137, ''),
#   Text(-0.3009298008125943, -1.0580365092863726, ''),
#   Text(0.6367174607891097, -0.8969898968919711, ''),
#   Text(1.0253457139591653, -0.3983292191963447, '')])

# %%
# plt.hist(years,oscar_revenue)

# %%
plt.boxplot(years)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x11ceed810>,
#   <matplotlib.lines.Line2D at 0x11ceed950>],
#  'caps': [<matplotlib.lines.Line2D at 0x11ceeda90>,
#   <matplotlib.lines.Line2D at 0x11ceedbd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x11ceed6d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x11ceedd10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11ceede50>],
#  'means': []}

# %%
# bar chart 
#vertical 
#horizontal

# %%
plt.bar(years,oscar_revenue)

plt.xlabel("Years")
plt.ylabel("Oscar_revenue")

plt.title("Revenue in each Year for oscar movies ")

for i in range(len(years)):
    plt.text(years[i],oscar_revenue[i]+10,str(oscar_revenue[i]),ha = "center")
     
plt.ylim(0,max(oscar_revenue)+100)
# plt.xlim(min(years),max(years)+5)
# Out:
# (0.0, 1105.0)
